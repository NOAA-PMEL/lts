# %%
import json
import pandas as pd
from sdig.erddap.info import Info
import numpy as np
import constants

# %%
datasets = 'datasets.json'
if datasets is not None:
    with open(datasets) as discovery_stream:
        datasets_json = json.load(discovery_stream)
sites = {}
for variable in datasets_json:
    sites_variable = {}
    for url in datasets_json[variable]['datasets']:
        info = Info(url)
        title = info.get_title()
        variables_list, long_names, units, standard_names, d_types = info.get_variables()
        locations = url + '.csv?site_code,wmo_platform_code,latitude,longitude&distinct()'
        print(locations)
        df = pd.read_csv(locations, skiprows=[1])
        if df.shape[0] > 1 and df.site_code.nunique() <= 1:
            adf = df.mean(axis=0, numeric_only=True)
            adf['site_code'] = df['site_code'].iloc[0]
            adf['wmo_platform_code'] = df['wmo_platform_code'].iloc[0]
            mdf = pd.DataFrame(columns=['latitude', 'longitude', 'site_code', 'wmo_platform_code'], index=[0], )
            mdf['latitude'] = adf.loc['latitude']
            mdf['longitude'] = adf.loc['longitude']
            mdf['site_code'] = adf.loc['site_code']
            df = mdf
        df['url'] = url
        df = df.set_index('site_code')
        url_sites = df.to_dict('index')
        for site in url_sites:
            if 'PRES' in variables_list:
                url_sites[site]['depth_name'] = 'PRES'
            elif 'depth' in variables_list:
                url_sites[site]['depth_name'] = 'depth'
            time_url = url + '.csv?site_code,time&orderByMinMax("time")&site_code="'+site+'"&'+datasets_json[variable]['short_names'][0]+'!=NaN'
            time_df = pd.read_csv(time_url, skiprows=[1])
            depth_url = url + '.csv?site_code,depth&distinct()&site_code="'+site+'"'
            depth_df = pd.read_csv(depth_url, skiprows=[1])
            url_sites[site]['depth_count'] = depth_df.shape[0]
            url_sites[site]['start_time'] = time_df['time'].min()
            url_sites[site]['end_time'] = time_df['time'].max()
            url_sites[site]['title'] = title
            url_sites[site]['units'] = units[datasets_json[variable]['short_names'][0]]
            url_sites[site]['depth_units'] = units[url_sites[site]['depth_name']]
            url_sites[site]['long_name'] = long_names[datasets_json[variable]['short_names'][0]]
            sites_variable[site] = url_sites[site]
    sites[variable] = sites_variable
for variable in sites:
    datasets_json[variable]['sites'] = sites[variable]
with open('sites.json', 'w') as fp:
    json.dump(datasets_json, fp, indent=4)
# Out:
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/keo_hourly.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/papa_hourly_temp.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/pirata_hourly_temp.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/rama_hourly_temp.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/NTAS_met.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/WHOTS_met.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/Stratus_met.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/keo_hourly.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/papa_hourly_psal.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/pirata_hourly_psal.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/rama_hourly_psal.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/NTAS_met.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/Stratus_met.csv?site_code,wmo_platform_code,latitude,longitude&distinct()
# https://data.pmel.noaa.gov/pmel/erddap/tabledap/WHOTS_met.csv?site_code,wmo_platform_code,latitude,longitude&distinct()

# %% [markdown]
# Everything below here is not currently used, but could be used in the future to set up databases for various parts of the config.

# %%
dft = pd.DataFrame.from_dict(datasets_json['temperature']['sites'], orient='index').reset_index().rename(columns={'index': 'site_code'})
dft['short_name'] = 'TEMP'

# %%
dfs = pd.DataFrame.from_dict(datasets_json['salinity']['sites'], orient='index').reset_index().rename(columns={'index': 'site_code'})
dfs['short_name'] = 'PSAL'

# %%
with constants.postgres_engine.connect() as conn:
    all.to_sql('config', index=False, con=conn)

# %%
with constants.postgres_engine.connect() as conn:
    cdf = conn.execute('DROP TABLE IF EXISTS config')
