# %%
import json
import pandas as pd
from sdig.erddap.info import Info
import numpy as np

# %%
datasets = 'datasets.json'
if datasets is not None:
    with open(datasets) as discovery_stream:
        datasets_json = json.load(discovery_stream)
sites = {}
for variable in datasets_json:
    sites_variable = {}
    for url in datasets_json[variable]['datasets']:
        info = Info(url)
        title = info.get_title()
        variables_list, long_names, units, standard_names, d_types = info.get_variables()
        locations = url + '.csv?site_code,wmo_platform_code,latitude,longitude&distinct()'
        df = pd.read_csv(locations, skiprows=[1])
        df['url'] = url
        df = df.set_index('site_code')
        url_sites = df.to_dict('index')
        for site in url_sites:
            if 'PRES' in variables_list:
                url_sites[site]['depth_name'] = 'PRES'
            elif 'depth' in variables_list:
                url_sites[site]['depth_name'] = 'depth'
            time_url = url + '.csv?site_code,time&orderByMinMax("time")&site_code="'+site+'"&'+datasets_json[variable]['short_names'][0]+'!=NaN'
            print(time_url)
            time_df = pd.read_csv(time_url, skiprows=[1])
            print(time_df)
            depth_url = url + '.csv?site_code,depth&distinct()&site_code="'+site+'"'
            depth_df = pd.read_csv(depth_url, skiprows=[1])
            url_sites[site]['depth_count'] = depth_df.shape[0]
            url_sites[site]['start_time'] = time_df['time'].min()
            url_sites[site]['end_time'] = time_df['time'].max()
            url_sites[site]['title'] = title
            url_sites[site]['units'] = units[datasets_json[variable]['short_names'][0]]
            url_sites[site]['depth_units'] = units[url_sites[site]['depth_name']]
            url_sites[site]['long_name'] = long_names[datasets_json[variable]['short_names'][0]]
            sites_variable[site] = url_sites[site]
    sites[variable] = sites_variable
for variable in sites:
    datasets_json[variable]['sites'] = sites[variable]
with open('sites.json', 'w') as fp:
    json.dump(datasets_json, fp, indent=4)
# Out:
# https://data.pmel.noaa.gov/generic/erddap/tabledap/keo_hourly.csv?site_code,time&orderByMinMax("time")&site_code="KEO"&TEMP!=NaN
#   site_code                  time
# 0       KEO  2004-06-16T12:00:00Z
# 1       KEO  2022-05-22T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/papa_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="Papa"&TEMP!=NaN
#   site_code                  time
# 0      Papa  2007-06-07T23:00:00Z
# 1      Papa  2022-05-16T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="0n23w"&TEMP!=NaN
#   site_code                  time
# 0     0n23w  2016-03-13T01:00:00Z
# 1     0n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="0n35w"&TEMP!=NaN
#   site_code                  time
# 0     0n35w  2017-11-07T02:00:00Z
# 1     0n35w  2019-03-28T14:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="10s10w"&TEMP!=NaN
#   site_code                  time
# 0    10s10w  2016-03-18T20:00:00Z
# 1    10s10w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="12n23w"&TEMP!=NaN
#   site_code                  time
# 0    12n23w  2015-11-28T22:00:00Z
# 1    12n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="15n38w"&TEMP!=NaN
#   site_code                  time
# 0    15n38w  2017-11-24T00:00:00Z
# 1    15n38w  2022-05-22T04:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="20n38w"&TEMP!=NaN
#   site_code                  time
# 0    20n38w  2017-03-17T01:00:00Z
# 1    20n38w  2022-05-22T08:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="21n23w"&TEMP!=NaN
#   site_code                  time
# 0    21n23w  2017-03-13T20:00:00Z
# 1    21n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="4n23w"&TEMP!=NaN
#   site_code                  time
# 0     4n23w  2017-03-06T21:00:00Z
# 1     4n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="4n38w"&TEMP!=NaN
#   site_code                  time
# 0     4n38w  2017-11-17T19:00:00Z
# 1     4n38w  2019-09-16T18:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="6s10w"&TEMP!=NaN
#   site_code                  time
# 0     6s10w  2019-03-23T19:00:00Z
# 1     6s10w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="6s8e"&TEMP!=NaN
#   site_code                  time
# 0      6s8e  2017-03-19T20:00:00Z
# 1      6s8e  2019-08-08T13:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="12n90e"&TEMP!=NaN
#   site_code                  time
# 0    12n90e  2017-01-12T10:00:00Z
# 1    12n90e  2021-01-29T16:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="12s67e"&TEMP!=NaN
#   site_code                  time
# 0    12s67e  2015-10-28T10:00:00Z
# 1    12s67e  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="12s80.5e"&TEMP!=NaN
#   site_code                  time
# 0  12s80.5e  2015-10-22T16:00:00Z
# 1  12s80.5e  2021-01-04T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="15n65e"&TEMP!=NaN
#   site_code                  time
# 0    15n65e  2018-06-19T08:00:00Z
# 1    15n65e  2020-10-21T04:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="4s67e"&TEMP!=NaN
#   site_code                  time
# 0     4s67e  2016-09-10T11:00:00Z
# 1     4s67e  2021-09-06T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="4s80.5e"&TEMP!=NaN
#   site_code                  time
# 0   4s80.5e  2015-08-30T14:00:00Z
# 1   4s80.5e  2021-01-09T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="8n90e"&TEMP!=NaN
#   site_code                  time
# 0     8n90e  2017-01-14T10:00:00Z
# 1     8n90e  2020-02-22T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="8s67e"&TEMP!=NaN
#   site_code                  time
# 0     8s67e  2015-10-29T16:00:00Z
# 1     8s67e  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_temp.csv?site_code,time&orderByMinMax("time")&site_code="8s80.5e"&TEMP!=NaN
#   site_code                  time
# 0   8s80.5e  2016-11-19T16:00:00Z
# 1   8s80.5e  2020-08-23T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/keo_hourly.csv?site_code,time&orderByMinMax("time")&site_code="KEO"&PSAL!=NaN
#   site_code                  time
# 0       KEO  2004-06-16T12:00:00Z
# 1       KEO  2022-05-22T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/papa_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="Papa"&PSAL!=NaN
#   site_code                  time
# 0      Papa  2007-06-07T23:00:00Z
# 1      Papa  2022-05-16T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="0n23w"&PSAL!=NaN
#   site_code                  time
# 0     0n23w  1999-03-06T14:00:00Z
# 1     0n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="0n35w"&PSAL!=NaN
#   site_code                  time
# 0     0n35w  1998-01-22T00:00:00Z
# 1     0n35w  2019-03-28T14:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="10s10w"&PSAL!=NaN
#   site_code                  time
# 0    10s10w  1998-11-04T10:00:00Z
# 1    10s10w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="12n23w"&PSAL!=NaN
#   site_code                  time
# 0    12n23w  1999-03-06T14:00:00Z
# 1    12n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="15n38w"&PSAL!=NaN
#   site_code                  time
# 0    15n38w  1998-01-27T19:00:00Z
# 1    15n38w  2022-05-22T04:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="20n38w"&PSAL!=NaN
#   site_code                  time
# 0    20n38w  2007-05-22T04:00:00Z
# 1    20n38w  2022-05-22T08:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="21n23w"&PSAL!=NaN
#   site_code                  time
# 0    21n23w  2006-06-11T11:00:00Z
# 1    21n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="4n23w"&PSAL!=NaN
#   site_code                  time
# 0     4n23w  2006-06-11T11:00:00Z
# 1     4n23w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="4n38w"&PSAL!=NaN
#   site_code                  time
# 0     4n38w  2000-03-20T02:00:00Z
# 1     4n38w  2019-09-16T18:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="6s10w"&PSAL!=NaN
#   site_code                  time
# 0     6s10w  2000-03-14T14:00:00Z
# 1     6s10w  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/pirata_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="6s8e"&PSAL!=NaN
#   site_code                  time
# 0      6s8e  2006-06-27T20:00:00Z
# 1      6s8e  2019-08-08T13:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="12n90e"&PSAL!=NaN
#   site_code                  time
# 0    12n90e  2007-11-15T12:00:00Z
# 1    12n90e  2021-01-29T16:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="12s67e"&PSAL!=NaN
#   site_code                  time
# 0    12s67e  2009-09-13T08:00:00Z
# 1    12s67e  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="12s80.5e"&PSAL!=NaN
#   site_code                  time
# 0  12s80.5e  2010-05-17T09:00:00Z
# 1  12s80.5e  2021-01-04T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="15n65e"&PSAL!=NaN
#   site_code                  time
# 0    15n65e  2018-06-19T08:00:00Z
# 1    15n65e  2020-10-21T04:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="4s67e"&PSAL!=NaN
#   site_code                  time
# 0     4s67e  2012-06-24T08:00:00Z
# 1     4s67e  2021-04-30T23:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="4s80.5e"&PSAL!=NaN
#   site_code                  time
# 0   4s80.5e  2008-08-19T11:00:00Z
# 1   4s80.5e  2021-01-09T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="8n90e"&PSAL!=NaN
#   site_code                  time
# 0     8n90e  2006-11-14T09:00:00Z
# 1     8n90e  2020-02-22T00:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="8s67e"&PSAL!=NaN
#   site_code                  time
# 0     8s67e  2007-01-13T14:00:00Z
# 1     8s67e  2022-05-22T06:00:00Z
# https://data.pmel.noaa.gov/generic/erddap/tabledap/rama_hourly_psal.csv?site_code,time&orderByMinMax("time")&site_code="8s80.5e"&PSAL!=NaN
#   site_code                  time
# 0   8s80.5e  2008-08-22T14:00:00Z
# 1   8s80.5e  2020-08-23T00:00:00Z

# %%
df = pd.DataFrame.from_dict(datasets_json['temperature']['sites'], orient='index').reset_index().rename(columns={'index': 'site_code'})
df
# Out:
#    site_code  wmo_platform_code  latitude  longitude  \
# 0        KEO              28401      32.3      144.6
# 1       Papa              48400      50.1     -144.9
# 2      0n23w              31007       0.0      -23.0
# 3      0n35w              31001       0.0      -35.0
# 4     10s10w              15001     -10.0      -10.0
# 5     12n23w              13001      12.0      -23.0
# 6     15n38w              13008      15.0      -38.0
# 7     20n38w              41139      20.0      -38.0
# 8     21n23w              13002      21.0      -23.0
# 9      4n23w              31006       4.0      -23.0
# 10     4n38w              31002       4.0      -38.0
# 11     6s10w              15006      -6.0      -10.0
# 12      6s8e              15007      -6.0        8.0
# 13    12n90e              23008      12.0       90.0
# 14    12s67e              14043     -12.0       67.0
# 15  12s80.5e              53006     -12.0       80.5
# 16    15n65e              23011      15.0       65.0
# 17     4s67e              23017      -4.0       67.0
# 18   4s80.5e              23010      -4.0       80.5
# 19     8n90e              23007       8.0       90.0
# 20     8s67e              14040      -8.0       67.0
# 21   8s80.5e              53005      -8.0       80.5
#
#                                                   url depth_name  depth_count  \
# 0   https://data.pmel.noaa.gov/generic/erddap/tabl...       PRES           32
# 1   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           24
# 2   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           13
# 3   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 4   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           13
# 5   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           13
# 6   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           13
# 7   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 8   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 9   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 10  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 11  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 12  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           16
# 13  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 14  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 15  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 16  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           13
# 17  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 18  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 19  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
# 20  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           17
# 21  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           12
#
#               start_time              end_time  \
# 0   2004-06-16T12:00:00Z  2022-05-22T00:00:00Z
# 1   2007-06-07T23:00:00Z  2022-05-22T00:00:00Z
# 2   1999-03-06T14:00:00Z  2022-05-22T06:00:00Z
# 3   1998-01-22T00:00:00Z  2020-05-01T00:00:00Z
# 4   1998-11-04T10:00:00Z  2022-05-22T06:00:00Z
# 5   1999-03-06T14:00:00Z  2022-05-22T06:00:00Z
# 6   1998-01-27T19:00:00Z  2022-05-22T06:00:00Z
# 7   2007-05-22T04:00:00Z  2022-05-22T08:00:00Z
# 8   2006-06-11T11:00:00Z  2022-05-22T06:00:00Z
# 9   2006-06-11T11:00:00Z  2022-05-22T06:00:00Z
# 10  2000-03-20T02:00:00Z  2019-09-16T18:00:00Z
# 11  2000-03-14T14:00:00Z  2022-05-22T06:00:00Z
# 12  2006-06-27T20:00:00Z  2019-08-08T13:00:00Z
# 13  2007-11-15T12:00:00Z  2021-03-17T03:00:00Z
# 14  2009-09-13T08:00:00Z  2022-05-22T06:00:00Z
# 15  2010-05-17T09:00:00Z  2022-05-22T06:00:00Z
# 16  2018-06-19T08:00:00Z  2020-10-21T04:00:00Z
# 17  2012-06-24T08:00:00Z  2021-09-06T00:00:00Z
# 18  2008-08-19T11:00:00Z  2021-01-09T00:00:00Z
# 19  2006-11-14T09:00:00Z  2020-02-22T00:00:00Z
# 20  2007-01-13T14:00:00Z  2022-05-22T06:00:00Z
# 21  2008-08-22T14:00:00Z  2020-08-23T00:00:00Z
#
#                                                 title           units  \
# 0   OceanSITES KEO in-situ data: Hourly High Resol...  degree_Celsius
# 1            OceanSITES Papa hourly TEMP in-situ data  degree_Celsius
# 2          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 3          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 4          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 5          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 6          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 7          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 8          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 9          OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 10         OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 11         OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 12         OceanSITES PIRATA hourly TEMP in-situ data  degree_Celsius
# 13           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 14           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 15           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 16           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 17           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 18           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 19           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 20           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
# 21           OceanSITES RAMA hourly TEMP in-situ data  degree_Celsius
#
#    depth_units    long_name
# 0      decibar  Temperature
# 1            m  Temperature
# 2            m  Temperature
# 3            m  Temperature
# 4            m  Temperature
# 5            m  Temperature
# 6            m  Temperature
# 7            m  Temperature
# 8            m  Temperature
# 9            m  Temperature
# 10           m  Temperature
# 11           m  Temperature
# 12           m  Temperature
# 13           m  Temperature
# 14           m  Temperature
# 15           m  Temperature
# 16           m  Temperature
# 17           m  Temperature
# 18           m  Temperature
# 19           m  Temperature
# 20           m  Temperature
# 21           m  Temperature

# %%
df = pd.DataFrame.from_dict(datasets_json['salinity']['sites'], orient='index').reset_index().rename(columns={'index': 'site_code'})
df
# Out:
#    site_code  wmo_platform_code  latitude  longitude  \
# 0        KEO              28401      32.3      144.6
# 1       Papa              48400      50.1     -144.9
# 2      0n23w              31007       0.0      -23.0
# 3      0n35w              31001       0.0      -35.0
# 4     10s10w              15001     -10.0      -10.0
# 5     12n23w              13001      12.0      -23.0
# 6     15n38w              13008      15.0      -38.0
# 7     20n38w              41139      20.0      -38.0
# 8     21n23w              13002      21.0      -23.0
# 9      4n23w              31006       4.0      -23.0
# 10     4n38w              31002       4.0      -38.0
# 11     6s10w              15006      -6.0      -10.0
# 12      6s8e              15007      -6.0        8.0
# 13    12n90e              23008      12.0       90.0
# 14    12s67e              14043     -12.0       67.0
# 15  12s80.5e              53006     -12.0       80.5
# 16    15n65e              23011      15.0       65.0
# 17     4s67e              23017      -4.0       67.0
# 18   4s80.5e              23010      -4.0       80.5
# 19     8n90e              23007       8.0       90.0
# 20     8s67e              14040      -8.0       67.0
# 21   8s80.5e              53005      -8.0       80.5
#
#                                                   url depth_name  depth_count  \
# 0   https://data.pmel.noaa.gov/generic/erddap/tabl...       PRES           32
# 1   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           20
# 2   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            8
# 3   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 4   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            9
# 5   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            8
# 6   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            8
# 7   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 8   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 9   https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 10  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            5
# 11  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            9
# 12  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           10
# 13  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 14  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 15  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 16  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            8
# 17  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 18  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 19  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
# 20  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth           15
# 21  https://data.pmel.noaa.gov/generic/erddap/tabl...      depth            6
#
#               start_time              end_time  \
# 0   2004-06-16T12:00:00Z  2022-05-22T00:00:00Z
# 1   2007-06-07T23:00:00Z  2022-05-22T00:00:00Z
# 2   1999-03-06T14:00:00Z  2022-05-22T06:00:00Z
# 3   1998-01-22T00:00:00Z  2020-05-01T00:00:00Z
# 4   1998-11-04T10:00:00Z  2022-05-22T06:00:00Z
# 5   1999-03-06T14:00:00Z  2022-05-22T06:00:00Z
# 6   1998-01-27T19:00:00Z  2022-05-22T06:00:00Z
# 7   2007-05-22T04:00:00Z  2022-05-22T08:00:00Z
# 8   2006-06-11T11:00:00Z  2022-05-22T06:00:00Z
# 9   2006-06-11T11:00:00Z  2022-05-22T06:00:00Z
# 10  2000-03-20T02:00:00Z  2019-09-16T18:00:00Z
# 11  2000-03-14T14:00:00Z  2022-05-22T06:00:00Z
# 12  2006-06-27T20:00:00Z  2019-08-08T13:00:00Z
# 13  2007-11-15T12:00:00Z  2021-03-17T03:00:00Z
# 14  2009-09-13T08:00:00Z  2022-05-22T06:00:00Z
# 15  2010-05-17T09:00:00Z  2022-05-22T06:00:00Z
# 16  2018-06-19T08:00:00Z  2020-10-21T04:00:00Z
# 17  2012-06-24T08:00:00Z  2021-09-06T00:00:00Z
# 18  2008-08-19T11:00:00Z  2021-01-09T00:00:00Z
# 19  2006-11-14T09:00:00Z  2020-02-22T00:00:00Z
# 20  2007-01-13T14:00:00Z  2022-05-22T06:00:00Z
# 21  2008-08-22T14:00:00Z  2020-08-23T00:00:00Z
#
#                                                 title units depth_units  \
# 0   OceanSITES KEO in-situ data: Hourly High Resol...   PSU     decibar
# 1   OceanSITES Papa hourly PSAL in-situ data (Ocea...   PSU           m
# 2          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 3          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 4          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 5          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 6          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 7          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 8          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 9          OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 10         OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 11         OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 12         OceanSITES PIRATA hourly PSAL in-situ data   PSU           m
# 13           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 14           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 15           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 16           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 17           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 18           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 19           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 20           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
# 21           OceanSITES RAMA hourly PSAL in-situ data   PSU           m
#
#    long_name
# 0   Salinity
# 1   Salinity
# 2   Salinity
# 3   Salinity
# 4   Salinity
# 5   Salinity
# 6   Salinity
# 7   Salinity
# 8   Salinity
# 9   Salinity
# 10  Salinity
# 11  Salinity
# 12  Salinity
# 13  Salinity
# 14  Salinity
# 15  Salinity
# 16  Salinity
# 17  Salinity
# 18  Salinity
# 19  Salinity
# 20  Salinity
# 21  Salinity
